# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1
#
# Each line of code below contains an **error**. Fix the error and explain in a comment the reason for the error.

# %% [markdown]
# 1. Print('Hello world!')
#
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 Print('Hello world!')
#
# NameError: name 'Print' is not defined

# %%
print('Hello world!') #the error is name error print function must be all small letters
# Out:
# Hello world!

# %% [markdown]
# 2. print'Hello world!')
#
#   Cell In[18], line 1
#     print'Hello world!')
#
# SyntaxError: unmatched ')'

# %%
print('Hello world!') #the syntax has a missing open parenthesis
# Out:
# Hello world!

# %% [markdown]
# 3. print('Hello world!)
#
# Cell In[19], line 1
#     print('Hello world!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world!') #print text has a missing single quotataion
# Out:
# Hello world!

# %% [markdown]
# 4. print('Hello world!'')
#
#   Cell In[20], line 1
#     print('Hello world!'')
#
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world!') #print text has another single qoutation its should only pair
# Out:
# Hello world!

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x) #the output is 44 because x assigned 43 and x = x(43) plus 1 is equal to 44

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1 # the name x is capitalized
print(x) #the name "X" is not a defined variable

# %% [markdown]
# mark
