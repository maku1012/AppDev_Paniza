# %% [markdown]
# #### Exercise 2
# - Create your own module.
# - Place variables and functions inside it.
# - Import your module and use the variabls and functions you've created in the module.
# - Try to add docstrings for the module and the functions
#
# [あ]

# %%
# %%writefile myModule.py
def sum(x, y):
  return x + y
  """
  this function is for addition of two variables
  """

def diff(x, y):
  return x - y
  """
  this function is for the difference of two variables
  """
def greetings(name):
  return f"Hello {name}."

test = "Hi How are ya"
# Out:
# Writing myModule.py

# %%
import myModule as m
print(m.test)
print(m.sum(3,1222233))
print(m.diff(129232342,12212909))
print(m.greetings("Mark Lorenze Paniza"))
# Out:
# Hi How are ya
# 1222236
# 117019433
# Hello Mark Lorenze Paniza.
